# %% [markdown]
# # Import Module

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
yf.pdr_override()
import mplfinance as mpf

# %% [markdown]
# # Get Bitcoin Information (in USD)

# %%
bitcoin_usd = yf.Ticker("BTC-USD")
bitcoin_usd.info
# Out:
# {'companyOfficers': [],
#  'name': 'Bitcoin',
#  'startDate': 1367107200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency . Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 18,735,925. The last known price of Bitcoin is 40,037.56030281 USD and is down -0.12 over the last 24 hours. It is currently trading on 9106 active market(s) with $39,335,357,124.62 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'maxAge': 1,
#  'previousClose': 40023.758,
#  'regularMarketOpen': 40023.758,
#  'twoHundredDayAverage': 42641.43,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': 38297108480,
#  'regularMarketDayHigh': 40472.22,
#  'navPrice': None,
#  'averageDailyVolume10Day': 41761620707,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 40023.758,
#  'fiftyDayAverage': 44413.97,
#  'trailingAnnualDividendRate': None,
#  'open': 40023.758,
#  'toCurrency': 'USD=X',
# ...

# %% [markdown]
# ## Fetch Historical Data

# %%
# Valid period includes: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
# Default is '1mo'

dataset = bitcoin_usd.history(period='1y')

# %% [markdown]
# ## Check data

# %%
dataset.head()
# Out:
#                Open     High      Low    Close       Volume  Dividends  \
# Date
# 2020-06-16  9454.27  9579.43  9400.45  9538.02  21565537209          0
# 2020-06-17  9533.78  9540.42  9327.34  9480.25  20177709879          0
# 2020-06-18  9481.57  9482.78  9328.40  9411.84  17770083003          0
# 2020-06-19  9410.29  9440.88  9274.30  9288.02  19632223107          0
# 2020-06-20  9290.96  9394.97  9247.38  9332.34  17130541557          0
#
#             Stock Splits
# Date
# 2020-06-16             0
# 2020-06-17             0
# 2020-06-18             0
# 2020-06-19             0
# 2020-06-20             0

# %%
dataset.tail()
# Out:
#                 Open      High       Low     Close       Volume  Dividends  \
# Date
# 2021-06-12  37340.14  37408.93  34728.19  35552.52  37924228550          0
# 2021-06-13  35555.79  39322.78  34864.11  39097.86  40669112838          0
# 2021-06-14  39016.97  40978.36  38757.29  40536.07  48513128441          0
# 2021-06-15  40526.78  41295.27  39609.47  40155.30  40231530708          0
# 2021-06-16  40023.76  40472.22  39746.02  40060.20  38297108480          0
#
#             Stock Splits
# Date
# 2021-06-12             0
# 2021-06-13             0
# 2021-06-14             0
# 2021-06-15             0
# 2021-06-16             0

# %%
dataset.describe().T
# Out:
#               count          mean           std           min           25%  \
# Open          363.0  2.874433e+04  1.830469e+04  9.048460e+03  1.138574e+04
# High          363.0  2.962748e+04  1.889604e+04  9.162180e+03  1.154284e+04
# Low           363.0  2.776398e+04  1.756881e+04  8.975530e+03  1.121994e+04
# Close         363.0  2.882220e+04  1.828465e+04  9.045390e+03  1.139735e+04
# Volume        363.0  4.416463e+10  2.717885e+10  1.225260e+10  2.440909e+10
# Dividends     363.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Stock Splits  363.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                        50%           75%           max
# Open          2.130835e+04  4.659320e+04  6.352375e+04
# High          2.323860e+04  4.841713e+04  6.486310e+04
# Low           2.123468e+04  4.514102e+04  6.220896e+04
# Close         2.280308e+04  4.662065e+04  6.350346e+04
# Volume        4.023153e+10  5.826126e+10  3.509679e+11
# ...

# %% [markdown]
# # Data Visualisation
# There are 4 kinds of chart been used frequently, which are Line Chart, Bar Chart, Candlestrik Chart, Renko Chart, and Point and Figure Chart.
# * **Line chart** is a simple graphic display of price trends over time. It has one data point per time interval.
# * **Bar chart** has four bits of data in each entry, which are the high and low price encountered during the time interval, the opening and closing prices. From bar chart, analysts can immediately gets a sense of the nature of the time interval's trading.
# * **Candlestick chart** also provides four prices per data point entry : the high and low prices, and the opening and closing prices during the period. The body of the candle is shaded or clear due to price difference of opening and closing. Compared to Bar Chart, Candlestick Chart is more visible.
# * **Renko chart** looks like a series of bricks. A new brick is created when the price moves a specified price amount.
# * **Point and figure chart** was widely used in US in the early 1900s. Neither time nor volume are represented in the chart. To draw the point and figure chart, we have to decide the box size and the reversal size.

# %% [markdown]
# ## Line Chart

# %%
mpf.plot(dataset, type='line')

# %% [markdown]
# ## Bar Chart

# %%
mpf.plot(dataset)

# %% [markdown]
# ### Concerning Specific Data Slice

# %%
mpf.plot(dataset['2021'])

# %% [markdown]
# ## Candlestrik Chart

# %%
mpf.plot(dataset, type='candle')

# %%
mpf.plot(dataset['2021'], type='candle')

# %% [markdown]
# ## Renko chart

# %%
mpf.plot(dataset, type='renko')

# %%
mpf.plot(dataset['2021'], type='renko')

# %% [markdown]
# ## Point and figure chart

# %%
mpf.plot(dataset, type='pnf')

# %%
mpf.plot(dataset['2021'], type='pnf')

# %% [markdown]
# # Further Analysis with Candlestick Chart

# %%
mpf.plot(dataset,type='candle', figsize=(15,10),mav=(5,8,13,21),volume=True)
mpf.show()

# %%
mpf.plot(dataset['2021'],type='candle', figsize=(15,10),mav=(5,8,13,21),volume=True)
mpf.show()
